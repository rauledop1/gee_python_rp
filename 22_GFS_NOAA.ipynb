# %%
import geemap
import ee
import pandas as pd
from sqlalchemy import create_engine

# %%
SAP_PREDIO=f'''SELECT OBJECTID, IDAREA, IDPREDIO, IDTIPOREGIMENDOMINIO, SUPERFICIEHA, ESTADO_ID, ESTADO_VIGENCIA, ETIQUETA, GLOSALEGADA, NOMBRE, PORCEN_PROPIEDAD, REFERENCIA, ULTIMORODAL, GDB_GEOMATTR_DATA, SHAPE.ST_AsText()  AS wkt FROM ARAUCARIA.PREDIO p 
WHERE OBJECTID > 0
ORDER BY OBJECTID desc'''

# %%
engine_sap = create_engine('hana://araucaria_lectura:Ar4ucar14@clsaparaprd01.arauco.cl:32015')
predio = pd.read_sql(SAP_PREDIO, engine_sap)

# %%
predio.to_csv('Predios_hana.csv')

# %%
predio.head()
# Out:
#    objectid  idarea  idpredio  idtiporegimendominio  superficieha  estado_id  \
# 0     37861      52     72148                     1  1.149192e+06          0
# 1     37841      52     72147                    19  2.437741e+06          0
# 2     37821      52     72146                    19  4.056738e+06          0
# 3     37801      52     72145                    19  3.152204e+06          0
# 4     37781      52     72144                    19  2.810999e+06          0
#
#    estado_vigencia etiqueta glosalegada         nombre  porcen_propiedad  \
# 0                1     None        None     BELA IDEIA             100.0
# 1                1     None        None    REGO D AGUA             100.0
# 2                1     None        None          JUARA             100.0
# 3                1     None        None     PIO DO JAO             100.0
# 4                1     None        None  ESPERANCA LFG             100.0
#
#   referencia  ultimorodal gdb_geomattr_data  \
# 0       None            0              None
# 1       None            0              None
# 2       None            0              None
# 3       None            0              None
# 4       None            0              None
#
#                                                  wkt
# 0  MULTIPOLYGON (((-52.203260586 -19.977999865,-5...
# 1  POLYGON ((-52.263515457 -19.753892787,-52.2637...
# 2  POLYGON ((-52.679421111 -19.82582944,-52.67950...
# 3  POLYGON ((-51.66626639 -19.71505833,-51.666379...
# 4  POLYGON ((-52.88591472 -20.229781109,-52.88600...
